# %% [markdown]
# # Notebook to validate a training dataset

# %%
import polars as pl
import polars.selectors as cs

# %%
source = "s3://arthurmanceau/election_modeling_uhcp/data/derived/processed/data_processed_presidentiel_legislative_from1800_to2027_20260623_174327.parquet"

# %%
data = pl.scan_parquet(
    source,
    storage_options={
        "aws_endpoint_url": "https://minio.lab.sspcloud.fr",
        "aws_region": "us-east-1",
    },
    credential_provider=pl.CredentialProviderAWS(
        profile_name="default",
        region_name="us-east-1",
    ),
).collect()

# %%
res2022 = pl.scan_parquet(
    "s3://arthurmanceau/election_modeling_uhcp/data/raw/elections/presidentiel/2022/pres2022_csv/pres2022comm.parquet",
    storage_options={
        "aws_endpoint_url": "https://minio.lab.sspcloud.fr",
        "aws_region": "us-east-1",
    },
    credential_provider=pl.CredentialProviderAWS(
        profile_name="default",
        region_name="us-east-1",
    ),
).collect()

# %%
data
# Out:
# shape: (1_865_274, 1_945)
# ┌─────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ dep ┆ nomdep     ┆ codecommun ┆ nomcommune ┆ … ┆ F_rank_ter ┆ F_rank_ter ┆ F_rank_te ┆ F_rank_na │
# │ --- ┆ ---        ┆ e          ┆ ---        ┆   ┆ rescommune ┆ rescommune ┆ rrescommu ┆ ticommune │
# │ str ┆ str        ┆ ---        ┆ str        ┆   ┆ s/psurface ┆ s/surface  ┆ nes/surfa ┆ s/frarapa │
# │     ┆            ┆ str        ┆            ┆   ┆ …          ┆ ---        ┆ ce5…      ┆ t         │
# │     ┆            ┆            ┆            ┆   ┆ ---        ┆ f64        ┆ ---       ┆ ---       │
# │     ┆            ┆            ┆            ┆   ┆ f64        ┆            ┆ f64       ┆ f64       │
# ╞═════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 01  ┆ AIN        ┆ 01002      ┆ ABERGEMENT ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │     ┆            ┆            ┆ -DE-VAREY  ┆   ┆            ┆            ┆           ┆           │
# │ 01  ┆ AIN        ┆ 01004      ┆ AMBERIEU-E ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │     ┆            ┆            ┆ N-BUGEY    ┆   ┆            ┆            ┆           ┆           │
# │ 01  ┆ AIN        ┆ 01005      ┆ AMBERIEUX- ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │     ┆            ┆            ┆ EN-DOMBES  ┆   ┆            ┆            ┆           ┆           │
# │ 01  ┆ AIN        ┆ 01006      ┆ AMBLEON    ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │ 01  ┆ AIN        ┆ 01007      ┆ AMBRONAY   ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │ …   ┆ …          ┆ …          ┆ …          ┆ … ┆ …          ┆ …          ┆ …         ┆ …         │
# │ 95  ┆ Val-d'Oise ┆ 95676      ┆ Villers-en ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │     ┆            ┆            ┆ -Arthies   ┆   ┆            ┆            ┆           ┆           │
# │ 95  ┆ Val-d'Oise ┆ 95678      ┆ Villiers-A ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │     ┆            ┆            ┆ dam        ┆   ┆            ┆            ┆           ┆           │
# │ 95  ┆ Val-d'Oise ┆ 95680      ┆ Villiers-l ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │     ┆            ┆            ┆ e-Bel      ┆   ┆            ┆            ┆           ┆           │
# │ 95  ┆ Val-d'Oise ┆ 95682      ┆ Villiers-l ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │     ┆            ┆            ┆ e-Sec      ┆   ┆            ┆            ┆           ┆           │
# │ 95  ┆ Val-d'Oise ┆ 95690      ┆ Wy-dit-Jol ┆ … ┆ null       ┆ null       ┆ null      ┆ null      │
# │     ┆            ┆            ┆ i-Village  ┆   ┆            ┆            ┆           ┆           │
# └─────┴────────────┴────────────┴────────────┴───┴────────────┴────────────┴───────────┴───────────┘

# %%
data.filter(pl.col("election_code") == "pres2022").select(
    "votants"
).sum() / data.filter(pl.col("election_code") == "pres2022").select("inscrits").sum()
# Out:
# shape: (1, 1)
# ┌──────────┐
# │ votants  │
# │ ---      │
# │ f64      │
# ╞══════════╡
# │ 0.761969 │
# └──────────┘

# %%
data.select("distancelyon", "codecommune", "distanceparis", "distancemarseille")
# Out:
# shape: (1_865_274, 4)
# ┌──────────────┬─────────────┬───────────────┬───────────────────┐
# │ distancelyon ┆ codecommune ┆ distanceparis ┆ distancemarseille │
# │ ---          ┆ ---         ┆ ---           ┆ ---               │
# │ f64          ┆ str         ┆ f64           ┆ f64               │
# ╞══════════════╪═════════════╪═══════════════╪═══════════════════╡
# │ 70.407981    ┆ 01002       ┆ 465.516148    ┆ 299.96559         │
# │ 62.612627    ┆ 01004       ┆ 464.710962    ┆ 294.598979        │
# │ 28.131926    ┆ 01005       ┆ 426.324004    ┆ 303.482139        │
# │ 82.795745    ┆ 01006       ┆ 498.723886    ┆ 272.014169        │
# │ 63.178585    ┆ 01007       ┆ 460.127188    ┆ 299.571594        │
# │ …            ┆ …           ┆ …             ┆ …                 │
# │ 507.380133   ┆ 95676       ┆ 73.673622     ┆ 760.709345        │
# │ 469.072861   ┆ 95678       ┆ 26.839418     ┆ 730.237746        │
# │ 452.403581   ┆ 95680       ┆ 17.765166     ┆ 715.444525        │
# │ 459.47055    ┆ 95682       ┆ 24.510728     ┆ 722.879988        │
# │ 501.102325   ┆ 95690       ┆ 64.431764     ┆ 756.067662        │
# └──────────────┴─────────────┴───────────────┴───────────────────┘

# %%
# 1) For each numeric column, compute its minimum
mins = data.filter(pl.col("annee") < 2022).select(cs.starts_with("F_raw").min())

# 2) Get names of columns whose minimum is < 0
neg_cols = [
    name for name, val in zip(mins.columns, mins.row(0)) if val is not None and val < 0
]
neg_cols
# Out:
# []

# %%
# Uniquness
assert data.select("codecommune", "election_code").unique().height == data.height

# %%
data.columns
len(data.columns)
# Out:
# 1945

# %%
data.select(
    "dep",
    "nomdep",
    "codecommune",
    "nomcommune",
    "annee",
    "election_type",
    "type",
    "election_code",
    "no_inscrits",
    "no_votants",
    "exprimes_",
    "TYPECOM",
    "NCC",
    "NCCENR",
    "LIBELLE",
    "lat",
    "long",
    "distanceparis",
    "inscrits",
    "votants",
    "exprimes",
    "abstentions",
    "blancsnuls",
    "pvotepar",
    "pvoteabs",
    "pvoteblancsnuls",
    "pvoteexpr",
    "voteG",
    "voteCG",
    "voteC",
    "voteCD",
    "voteD",
    "voteTD",
    "voteTG",
    "voteGCG",
    "voteDCD",
    "pvoteG",
    "pvoteCG",
    "pvoteC",
    "pvoteCD",
    "pvoteD",
    "pvoteTD",
    "pvoteTG",
    "pvoteGCG",
    "pvoteDCD",
).null_count()
# Out:
# shape: (1, 45)
# ┌─────┬────────┬─────────────┬────────────┬───┬─────────┬─────────┬──────────┬──────────┐
# │ dep ┆ nomdep ┆ codecommune ┆ nomcommune ┆ … ┆ pvoteTD ┆ pvoteTG ┆ pvoteGCG ┆ pvoteDCD │
# │ --- ┆ ---    ┆ ---         ┆ ---        ┆   ┆ ---     ┆ ---     ┆ ---      ┆ ---      │
# │ u32 ┆ u32    ┆ u32         ┆ u32        ┆   ┆ u32     ┆ u32     ┆ u32      ┆ u32      │
# ╞═════╪════════╪═════════════╪════════════╪═══╪═════════╪═════════╪══════════╪══════════╡
# │ 0   ┆ 0      ┆ 0           ┆ 0          ┆ … ┆ 14      ┆ 14      ┆ 14       ┆ 14       │
# └─────┴────────┴─────────────┴────────────┴───┴─────────┴─────────┴──────────┴──────────┘

# %% [markdown]
# - No null for identifiers
# - Some nulls due to change in geography (geography of 2026)
# - Very few nulls for vote results (exceptions)
# - Previous (null for change in geography and first election)
# - Tau (null for when the number of vote / inscrits) is 0

# %%
data.filter(pl.col("TYPECOM").is_null()).group_by("election_code").agg(
    pl.col("annee").max(), pl.count("codecommune")
).sort("annee")
# Out:
# shape: (54, 3)
# ┌───────────────┬───────┬─────────────┐
# │ election_code ┆ annee ┆ codecommune │
# │ ---           ┆ ---   ┆ ---         │
# │ str           ┆ i64   ┆ u32         │
# ╞═══════════════╪═══════╪═════════════╡
# │ leg1848       ┆ 1848  ┆ 342         │
# │ pres1848      ┆ 1848  ┆ 342         │
# │ leg1849       ┆ 1849  ┆ 342         │
# │ leg1871       ┆ 1871  ┆ 187         │
# │ leg1872       ┆ 1872  ┆ 187         │
# │ …             ┆ …     ┆ …           │
# │ pres2017      ┆ 2017  ┆ 114         │
# │ pres2022      ┆ 2022  ┆ 15          │
# │ leg2022       ┆ 2022  ┆ 19          │
# │ leg2024       ┆ 2024  ┆ 12          │
# │ pres2027      ┆ 2027  ┆ 15          │
# └───────────────┴───────┴─────────────┘

# %%
data.select(cs.starts_with("pvotetau")).null_count()
# Out:
# shape: (1, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ pvotetauG ┆ pvotetauC ┆ pvotetauC ┆ pvotetauC ┆ … ┆ pvotetauT ┆ pvotetauG ┆ pvotetauD ┆ pvotetau │
# │ ---       ┆ G         ┆ ---       ┆ D         ┆   ┆ G         ┆ CG        ┆ CD        ┆ par      │
# │ u32       ┆ ---       ┆ u32       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ u32       ┆           ┆ u32       ┆   ┆ u32       ┆ u32       ┆ u32       ┆ u32      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 14891     ┆ 14891     ┆ 14891     ┆ 14891     ┆ … ┆ 14891     ┆ 14891     ┆ 14891     ┆ 14719    │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
data.select(cs.starts_with("percentile")).null_count()
# Out:
# shape: (1, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ percentil ┆ percentil ┆ percentil ┆ percentil ┆ … ┆ percentil ┆ percentil ┆ percentil ┆ percenti │
# │ epvoteG   ┆ epvoteCG  ┆ epvoteC   ┆ epvoteCD  ┆   ┆ epvoteTG  ┆ epvoteGCG ┆ epvoteDCD ┆ lepvotep │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ar       │
# │ u32       ┆ u32       ┆ u32       ┆ u32       ┆   ┆ u32       ┆ u32       ┆ u32       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ u32      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 14        ┆ 14        ┆ 14        ┆ 14        ┆ … ┆ 14        ┆ 14        ┆ 14        ┆ 0        │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
data.select(cs.starts_with("previous")).null_count()
# Out:
# shape: (1, 84)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ previousi ┆ previousv ┆ previouse ┆ previousa ┆ … ┆ previousp ┆ previousp ┆ previousp ┆ previous │
# │ nscrits   ┆ otants    ┆ xprimes   ┆ bstention ┆   ┆ reviouspv ┆ reviouspv ┆ reviouspv ┆ previous │
# │ ---       ┆ ---       ┆ ---       ┆ s         ┆   ┆ otetauTG  ┆ otetauGCG ┆ otetauDCD ┆ pvotetau │
# │ u32       ┆ u32       ┆ u32       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ par      │
# │           ┆           ┆           ┆ u32       ┆   ┆ u32       ┆ u32       ┆ u32       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ u32      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 73320     ┆ 73320     ┆ 73334     ┆ 73320     ┆ … ┆ 161442    ┆ 161442    ┆ 161442    ┆ 161301   │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# Missing values only either for no commune or all commune of the election

# %%
raw_columns = data.select(cs.starts_with("F_raw")).columns
data.select(raw_columns + ["election_code", "codecommune"]).group_by(
    "election_code"
).agg()
# Out:
# shape: (54, 1)
# ┌───────────────┐
# │ election_code │
# │ ---           │
# │ str           │
# ╞═══════════════╡
# │ pres1965      │
# │ pres1981      │
# │ leg2017       │
# │ leg1958       │
# │ leg2002       │
# │ …             │
# │ leg1968       │
# │ leg2012       │
# │ leg1889       │
# │ leg1914       │
# │ leg1932       │
# └───────────────┘

# %%
data.filter(pl.col("annee") == 1946).select(
    cs.starts_with("F_lag") | cs.contains("codecommune")
).join(
    data.filter(pl.col("annee") == 1945).select(
        cs.starts_with("F_raw") | cs.contains("codecommune")
    ),
    on="codecommune",
).select(cs.contains("perage"))
# Out:
# shape: (35_693, 2)
# ┌─────────────────────────────┬─────────────────────────────┐
# │ F_lag_agesexcommunes/perage ┆ F_raw_agesexcommunes/perage │
# │ ---                         ┆ ---                         │
# │ f64                         ┆ f64                         │
# ╞═════════════════════════════╪═════════════════════════════╡
# │ 0.5365                      ┆ 0.5365                      │
# │ 0.9986                      ┆ 0.9986                      │
# │ 0.4959                      ┆ 0.4959                      │
# │ 0.5189                      ┆ 0.5189                      │
# │ 0.99                        ┆ 0.99                        │
# │ …                           ┆ …                           │
# │ 0.9898                      ┆ 0.9898                      │
# │ 0.4352                      ┆ 0.4352                      │
# │ 0.0325                      ┆ 0.0325                      │
# │ 0.7322                      ┆ 0.7322                      │
# │ 0.3934                      ┆ 0.3934                      │
# └─────────────────────────────┴─────────────────────────────┘

# %%
data.filter(
    pl.col("F_rank_capitalimmobilierdepartements/surfaceterrain") < 0.05
).select("F_raw_capitalimmobilierdepartements/surfaceterrain")
# Out:
# shape: (2_877, 1)
# ┌─────────────────────────────────┐
# │ F_raw_capitalimmobilierdeparte… │
# │ ---                             │
# │ f64                             │
# ╞═════════════════════════════════╡
# │ 42.8766                         │
# │ 42.8766                         │
# │ 42.8766                         │
# │ 42.8766                         │
# │ 42.8766                         │
# │ …                               │
# │ 40.0576                         │
# │ 40.0576                         │
# │ 40.0576                         │
# │ 40.0576                         │
# │ 40.0576                         │
# └─────────────────────────────────┘

# %%
data.filter(
    pl.col("F_rank_capitalimmobilierdepartements/surfaceterrain") > 0.95
).select("F_raw_capitalimmobilierdepartements/surfaceterrain")
# Out:
# shape: (13_143, 1)
# ┌─────────────────────────────────┐
# │ F_raw_capitalimmobilierdeparte… │
# │ ---                             │
# │ f64                             │
# ╞═════════════════════════════════╡
# │ 660.2042                        │
# │ 660.2042                        │
# │ 660.2042                        │
# │ 660.2042                        │
# │ 660.2042                        │
# │ …                               │
# │ 642.9396                        │
# │ 642.9396                        │
# │ 642.9396                        │
# │ 642.9396                        │
# │ 642.9396                        │
# └─────────────────────────────────┘

# %%
data.filter(pl.col("annee") == 2022).select(cs.starts_with("F_rank")).describe()
# Out:
# shape: (9, 369)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ F_rank_ag ┆ F_rank_ag ┆ F_rank_ag ┆ … ┆ F_rank_te ┆ F_rank_te ┆ F_rank_te ┆ F_rank_n │
# │ ---       ┆ esexcommu ┆ esexcommu ┆ esexcommu ┆   ┆ rrescommu ┆ rrescommu ┆ rrescommu ┆ aticommu │
# │ str       ┆ nes/perag ┆ nes/perpr ┆ nes/perpr ┆   ┆ nes/psurf ┆ nes/surfa ┆ nes/surfa ┆ nes/frar │
# │           ┆ e         ┆ op0…      ┆ op6…      ┆   ┆ ace…      ┆ ce        ┆ ce5…      ┆ apat     │
# │           ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 69736.0   ┆ 69736.0   ┆ 69736.0   ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0      │
# │ null_coun ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ … ┆ 69736.0   ┆ 69736.0   ┆ 69736.0   ┆ 69736.0  │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ 0.464215  ┆ 0.463714  ┆ 0.464232  ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ std       ┆ 0.267592  ┆ 0.26751   ┆ 0.267568  ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ min       ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 25%       ┆ 0.2329    ┆ 0.2323    ┆ 0.233     ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 50%       ┆ 0.4645    ┆ 0.4634    ┆ 0.4645    ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ 75%       ┆ 0.6956    ┆ 0.695     ┆ 0.6957    ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ max       ┆ 0.9637    ┆ 0.9637    ┆ 0.9637    ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# Coherence of features

# %%
import matplotlib.pyplot as plt
import polars as pl


def plot_ts(data, codecommune="75111", features=None):
    if features is None:
        features = ["F_raw_cspcommunes/cadr"]

    cols = ["codecommune", "annee", *features]

    df = (
        data.select(cols)
        .unique(["codecommune", "annee"])
        .filter(pl.col("codecommune") == codecommune)
        .sort("annee")
    )

    pdf = df.to_pandas()

    plt.figure(figsize=(10, 4))
    for feature in features:
        plt.plot(pdf["annee"], pdf[feature], marker="o", label=feature)

    plt.title(f"Time series for codecommune {codecommune}")
    plt.xlabel("Année")
    plt.ylabel("Value")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
plot_ts(
    data,
    codecommune="18004",
    features=data.select(
        cs.ends_with("pop") & cs.contains("commune") & cs.contains("raw")
    ).columns,
)

# %%
plot_ts(
    data,
    codecommune="44131",
    features=[
        "F_raw_cspcommunes/pcadr",
        "F_raw_cspcommunes/pchom",
        "F_rank_cspcommunes/pcadr",
        "F_rank_cspcommunes/pchom",
    ],
)

# %%
plot_ts(
    data,
    codecommune="75111",
    features=[
        "F_raw_cspcommunes/pcadr",
        "F_raw_cspcommunes/pchom",
        "F_rank_cspcommunes/pcadr",
        "F_rank_cspcommunes/pchom",
    ],
)

# %%
# Saint-Denis
plot_ts(
    data,
    codecommune="93066",
    features=[
        "F_rank_etrangerscommunes/petranger",
        "F_raw_etrangerscommunes/petranger",
    ],
)

# %%
# Roubaix
plot_ts(
    data,
    codecommune="59512",
    features=[
        "F_rank_etrangerscommunes/petranger",
        "F_raw_etrangerscommunes/petranger",
        "F_pct_change_etrangerscommunes/petranger",
    ],
)
